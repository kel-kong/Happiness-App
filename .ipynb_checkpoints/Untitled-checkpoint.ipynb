# %%
import os
import pymysql
import pandas as pd

# %%
host = os.getenv('MYSQL_HOST')
port = os.getenv('MYSQL_PORT')
user = os.getenv('MYSQL_USER')
password = "mango123"
database = os.getenv('MYSQL_DATABASE')

# %%
conn = pymysql.connect(
    host=host,
    port=int(3306),
    user="root",
    passwd=password,
    db="happiness",
    charset='utf8mb4')

df = pd.read_sql_query("SELECT happiness.`2015`.`Happiness Rank` - happiness.`2016`.`Happiness Rank` AS 'Happiness Rank Difference' FROM happiness.`2016` INNER JOIN happiness.`2015` ON happiness.`2016`.`Country` = happiness.`2015`.`Country` WHERE happiness.`2016`.`Country` = 'Switzerland'", conn)
# Out:
# /Users/kelkong/opt/miniconda3/lib/python3.9/site-packages/pandas/io/sql.py:758: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#    Happiness Rank Difference
# 0                         -1

# %%
df = pd.read_sql_query("SELECT DISTINCT `Country` FROM `happiness`.`2015` ORDER BY `Country` ASC;", conn)
df
# Out:
# /Users/kelkong/opt/miniconda3/lib/python3.9/site-packages/pandas/io/sql.py:758: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#     Country or region
# 0         Afghanistan
# 1             Albania
# 2             Algeria
# 3           Argentina
# 4             Armenia
# ..                ...
# 151         Venezuela
# 152           Vietnam
# 153             Yemen
# 154            Zambia
# 155          Zimbabwe
#
# [156 rows x 1 columns]

# %%
df['Country'].to_list()
# Out:
# ['Afghanistan',
#  'Albania',
#  'Algeria',
#  'Angola',
#  'Argentina',
#  'Armenia',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Bahrain',
#  'Bangladesh',
#  'Belarus',
#  'Belgium',
#  'Benin',
#  'Bhutan',
#  'Bolivia',
#  'Bosnia and Herzegovina',
#  'Botswana',
#  'Brazil',
#  'Bulgaria',
#  'Burkina Faso',
#  'Burundi',
#  'Cambodia',
#  'Cameroon',
#  'Canada',
#  'Central African Republic',
#  'Chad',
#  'Chile',
#  'China',
#  'Colombia',
#  'Comoros',
#  'Congo (Brazzaville)',
#  'Congo (Kinshasa)',
#  'Costa Rica',
#  'Croatia',
#  'Cyprus',
#  'Czech Republic',
#  'Denmark',
#  'Djibouti',
#  'Dominican Republic',
#  'Ecuador',
#  'Egypt',
#  'El Salvador',
#  'Estonia',
#  'Ethiopia',
#  'Finland',
#  'France',
#  'Gabon',
#  'Georgia',
#  'Germany',
#  'Ghana',
#  'Greece',
#  'Guatemala',
#  'Guinea',
#  'Haiti',
#  'Honduras',
#  'Hong Kong',
#  'Hungary',
#  'Iceland',
#  'India',
#  'Indonesia',
#  'Iran',
#  'Iraq',
#  'Ireland',
#  'Israel',
#  'Italy',
# ...

# %%
region = pd.read_sql_query("SELECT DISTINCT `Region` FROM `happiness`.`2015` ORDER BY `Region` ASC;", conn)
regions_list = region['Region'].to_list()
regions_list.append("None")
regions_list
# Out:
# /Users/kelkong/opt/miniconda3/lib/python3.9/site-packages/pandas/io/sql.py:758: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# ['Australia and New Zealand',
#  'Central and Eastern Europe',
#  'Eastern Asia',
#  'Latin America and Caribbean',
#  'Middle East and Northern Africa',
#  'North America',
#  'Southeastern Asia',
#  'Southern Asia',
#  'Sub-Saharan Africa',
#  'Western Europe',
#  'None']

# %%
starting_year = 2015
ending_year = 2019
country = "Taiwan"
query = "select happiness.?.`Happiness Rank` - happiness.?.`Happiness Rank` AS 'Happiness Rank Difference' FROM happiness.? INNER JOIN happiness.? ON happiness.?.`Country` = happiness.?.`Country` WHERE happiness.`ending_year`.`Country` = ?;"
df = pd.read_sql_query(query, conn, params = [starting_year, ending_year, ending_year, starting_year, starting_year, ending_year, country])
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/opt/miniconda3/lib/python3.9/site-packages/pandas/io/sql.py:2017, in SQLiteDatabase.execute(self, *args, **kwargs)
#    2016 try:
# -> 2017     cur.execute(*args, **kwargs)
#    2018     return cur
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/pymysql/cursors.py:146, in Cursor.execute(self, query, args)
#     144     pass
# --> 146 query = self.mogrify(query, args)
#     148 result = self._query(query)
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/pymysql/cursors.py:125, in Cursor.mogrify(self, query, args)
#     124 if args is not None:
# --> 125     query = query % self._escape_args(args, conn)
#     127 return query
#
# TypeError: not all arguments converted during string formatting
#
# The above exception was the direct cause of the following exception:
#
# ...
